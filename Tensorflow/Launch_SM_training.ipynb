# %%
#!pip install --upgrade sagemaker sagemaker-experiments botocore==1.24.42

# %%
import os
from datetime import datetime

import boto3
from sagemaker import analytics, image_uris
from sagemaker.tensorflow import TensorFlow
from smexperiments.experiment import Experiment
from smexperiments.trial import Trial
from smexperiments.trial_component import TrialComponent
from smexperiments.tracker import Tracker
from sagemaker import get_execution_role
from sagemaker.debugger import (
    Rule,
    DebuggerHookConfig,
    TensorBoardOutputConfig,
    CollectionConfig,
    ProfilerConfig,
    FrameworkProfile,
    DetailedProfilingConfig,
    DataloaderProfilingConfig,
    rule_configs,
)
from smdebug.core.collection import CollectionKeys
# Out:
# Extension horovod.torch has not been built: /home/ec2-user/anaconda3/envs/tensorflow2_p38/lib/python3.8/site-packages/horovod/torch/mpi_lib/_mpi_lib.cpython-38-x86_64-linux-gnu.so not found
# If this is not expected, reinstall Horovod with HOROVOD_WITH_PYTORCH=1 to debug the build error.
# Warning! MPI libs are missing, but python applications are still avaiable.

# %%
time_str = datetime.now().strftime("%d-%m-%Y-%H-%M-%S")

region = boto3.session.Session().region_name
boto_sess = boto3.Session()
sm = boto_sess.client('sagemaker')

s3_bucket = "s3://jbsnyder-sagemaker-us-east/"

base_job_name = "jbsnyder-tf-resnet-debugger"
date_str = datetime.now().strftime("%d-%m-%Y")
time_str = datetime.now().strftime("%d-%m-%Y-%H-%M-%S")
job_name = f"{base_job_name}-{time_str}"

output_path = os.path.join(s3_bucket, "sagemaker-output", date_str, job_name)
code_location = os.path.join(s3_bucket, "sagemaker-code", date_str, job_name)

# %%
try: # Create new experiment
    experiment = Experiment.create(
        experiment_name=base_job_name,
        description='Resnet50 Classifier Training',
        sagemaker_boto_client=sm)
except: # Or reload existing
    experiment = Experiment.load(
        experiment_name=base_job_name,
        sagemaker_boto_client=sm)

trial = Trial.create(
    trial_name=job_name,
    experiment_name=experiment.experiment_name,
    sagemaker_boto_client=sm)
experiment_config = {
    'TrialName': trial.trial_name,
    'TrialComponentDisplayName': 'Training'}

# %%
tensorboard_output_config = TensorBoardOutputConfig(s3_output_path=os.path.join(output_path, 'tensorboard'))

# %%
collection_configs=[
    CollectionConfig(
        name="losses",
        parameters={
            "save_interval": "25",
            "reductions": "mean",
        }
    ),
    CollectionConfig(
        name=CollectionKeys.GRADIENTS,
        parameters={
            "save_interval": "100",
            "reductions": "mean",
        }
    )
]

debugger_hook_config=DebuggerHookConfig(
    collection_configs=collection_configs
)

# %%
profiler_config=ProfilerConfig(
    system_monitor_interval_millis=500,
)

# %%
hyperparameters = {"train_data_dir": os.path.join(s3_bucket, "data", "imagenet", "tfrecord", "train"), # "/opt/ml/input/data/train/", 
                   "validation_data_dir": os.path.join(s3_bucket, "data", "imagenet", "tfrecord", "validation"), # "/opt/ml/input/data/val/", 
                   "batch_size": 512,
                   "num_epochs": 5,
                   "model_dir": "/opt/ml/model",
                   "learning_rate": 0.08,
                   "momentum": 0.9,
                   "label_smoothing": 0.1,
                   "mixup_alpha": 0.1,
                   "l2_weight_decay": 1e-4,
                   "fp16": True,
                   "xla": False,
                   "tf32": False,
                   "model": "resnet50",
                   }

# %%
distribution = {"mpi": {"enabled": True}}
entry_point = "train.py"

# %%
instance_type = 'ml.p3.16xlarge'
instance_count = 1

image_uri = image_uris.retrieve(
    framework='tensorflow',
    region=region,
    version='2.7',
    py_version='py38',
    image_scope='training',
    instance_type=instance_type,
)

# %%
estimator = TensorFlow(
    source_dir="./src",
    entry_point=entry_point,
    base_job_name=job_name,
    role=get_execution_role(),
    instance_count=instance_count,
    instance_type=instance_type,
    distribution=distribution,
    volume_size=400,
    max_run=7200,
    hyperparameters=hyperparameters,
    image_uri=image_uri,
    output_path=os.path.join(output_path, 'training-output'),
    checkpoint_s3_uri=os.path.join(output_path, 'training-checkpoints'),
    model_dir=os.path.join(output_path, 'training-model'),
    code_location=code_location,
    ## Debugger parameters
    enable_sagemaker_metrics=True,
    # rules=rules,
    debugger_hook_config=debugger_hook_config,
    disable_profiler=False,
    tensorboard_output_config=tensorboard_output_config,
    profiler_config=profiler_config,
    input_mode='File',
)

# %%
# Run training
estimator.fit(
    inputs=None if hyperparameters['train_data_dir'].startswith('s3') else channels,
    wait=False,
    job_name=job_name,
    experiment_config=experiment_config,
)
# Out:
# INFO:sagemaker.image_uris:Defaulting to the only supported framework/algorithm version: latest.
# INFO:sagemaker.image_uris:Ignoring unnecessary instance type: None.
# INFO:sagemaker:Creating training-job with name: jbsnyder-tf-resnet-debugger-17-06-2022-23-24-32

# %%
estimator.logs()
# Out:
# 2022-06-17 23:24:38 Starting - Starting the training job...ProfilerReport-1655508275: InProgress
# ...
# 2022-06-17 23:25:34 Starting - Preparing the instances for training.........
# 2022-06-17 23:27:00 Downloading - Downloading input data...
# 2022-06-17 23:27:20 Training - Downloading the training image...............
# 2022-06-17 23:30:07 Training - Training image download completed. Training in progress..2022-06-17 23:30:11.218027: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2022-06-17 23:30:11.228351: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# 2022-06-17 23:30:11.536312: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# 2022-06-17 23:30:16,618 sagemaker-training-toolkit INFO     Imported framework sagemaker_tensorflow_container.training
# 2022-06-17 23:30:17,506 sagemaker-training-toolkit INFO     Starting MPI run as worker node.
# 2022-06-17 23:30:17,506 sagemaker-training-toolkit INFO     Creating SSH daemon.
# 2022-06-17 23:30:17,517 sagemaker-training-toolkit INFO     Waiting for MPI workers to establish their SSH connections
# 2022-06-17 23:30:17,517 sagemaker-training-toolkit INFO     Env Hosts: ['algo-1'] Hosts: ['algo-1:8'] process_per_hosts: 8 num_processes: 8
# 2022-06-17 23:30:17,519 sagemaker-training-toolkit INFO     Network interface name: eth0
# 2022-06-17 23:30:17,602 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {
#         "sagemaker_mpi_custom_mpi_options": "",
#         "sagemaker_mpi_enabled": true
#     },
#     "channel_input_dirs": {},
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_tensorflow_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "batch_size": 512,
#         "fp16": true,
#         "l2_weight_decay": 0.0001,
#         "label_smoothing": 0.1,
#         "learning_rate": 0.08,
#         "mixup_alpha": 0.1,
#         "model": "resnet50",
#         "model_dir": "s3://jbsnyder-sagemaker-us-east/sagemaker-output/17-06-2022/jbsnyder-tf-resnet-debugger-17-06-2022-23-24-32/training-model",
#         "momentum": 0.9,
#         "num_epochs": 5,
#         "tf32": false,
#         "train_data_dir": "s3://jbsnyder-sagemaker-us-east/data/imagenet/tfrecord/train",
#         "validation_data_dir": "s3://jbsnyder-sagemaker-us-east/data/imagenet/tfrecord/validation",
#         "xla": false
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {},
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "jbsnyder-tf-resnet-debugger-17-06-2022-23-24-32",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://jbsnyder-sagemaker-us-east/sagemaker-code/17-06-2022/jbsnyder-tf-resnet-debugger-17-06-2022-23-24-32/jbsnyder-tf-resnet-debugger-17-06-2022-23-24-32/source/sourcedir.tar.gz",
#     "module_name": "train",
#     "network_interface_name": "eth0",
#     "num_cpus": 64,
#     "num_gpus": 8,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.p3.16xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.p3.16xlarge",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"batch_size":512,"fp16":true,"l2_weight_decay":0.0001,"label_smoothing":0.1,"learning_rate":0.08,"mixup_alpha":0.1,"model":"resnet50","model_dir":"s3://jbsnyder-sagemaker-us-east/sagemaker-output/17-06-2022/jbsnyder-tf-resnet-debugger-17-06-2022-23-24-32/training-model","momentum":0.9,"num_epochs":5,"tf32":false,"train_data_dir":"s3://jbsnyder-sagemaker-us-east/data/imagenet/tfrecord/train","validation_data_dir":"s3://jbsnyder-sagemaker-us-east/data/imagenet/tfrecord/validation","xla":false}
# SM_USER_ENTRY_POINT=train.py
# SM_FRAMEWORK_PARAMS={"sagemaker_mpi_custom_mpi_options":"","sagemaker_mpi_enabled":true}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.p3.16xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.p3.16xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=[]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_tensorflow_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=64
# SM_NUM_GPUS=8
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://jbsnyder-sagemaker-us-east/sagemaker-code/17-06-2022/jbsnyder-tf-resnet-debugger-17-06-2022-23-24-32/jbsnyder-tf-resnet-debugger-17-06-2022-23-24-32/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{"sagemaker_mpi_custom_mpi_options":"","sagemaker_mpi_enabled":true},"channel_input_dirs":{},"current_host":"algo-1","framework_module":"sagemaker_tensorflow_container.training:main","hosts":["algo-1"],"hyperparameters":{"batch_size":512,"fp16":true,"l2_weight_decay":0.0001,"label_smoothing":0.1,"learning_rate":0.08,"mixup_alpha":0.1,"model":"resnet50","model_dir":"s3://jbsnyder-sagemaker-us-east/sagemaker-output/17-06-2022/jbsnyder-tf-resnet-debugger-17-06-2022-23-24-32/training-model","momentum":0.9,"num_epochs":5,"tf32":false,"train_data_dir":"s3://jbsnyder-sagemaker-us-east/data/imagenet/tfrecord/train","validation_data_dir":"s3://jbsnyder-sagemaker-us-east/data/imagenet/tfrecord/validation","xla":false},"input_config_dir":"/opt/ml/input/config","input_data_config":{},"input_dir":"/opt/ml/input","is_master":true,"job_name":"jbsnyder-tf-resnet-debugger-17-06-2022-23-24-32","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://jbsnyder-sagemaker-us-east/sagemaker-code/17-06-2022/jbsnyder-tf-resnet-debugger-17-06-2022-23-24-32/jbsnyder-tf-resnet-debugger-17-06-2022-23-24-32/source/sourcedir.tar.gz","module_name":"train","network_interface_name":"eth0","num_cpus":64,"num_gpus":8,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.p3.16xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.p3.16xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"train.py"}
# SM_USER_ARGS=["--batch_size","512","--fp16","True","--l2_weight_decay","0.0001","--label_smoothing","0.1","--learning_rate","0.08","--mixup_alpha","0.1","--model","resnet50","--model_dir","s3://jbsnyder-sagemaker-us-east/sagemaker-output/17-06-2022/jbsnyder-tf-resnet-debugger-17-06-2022-23-24-32/training-model","--momentum","0.9","--num_epochs","5","--tf32","False","--train_data_dir","s3://jbsnyder-sagemaker-us-east/data/imagenet/tfrecord/train","--validation_data_dir","s3://jbsnyder-sagemaker-us-east/data/imagenet/tfrecord/validation","--xla","False"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_HP_BATCH_SIZE=512
# SM_HP_FP16=true
# SM_HP_L2_WEIGHT_DECAY=0.0001
# SM_HP_LABEL_SMOOTHING=0.1
# SM_HP_LEARNING_RATE=0.08
# SM_HP_MIXUP_ALPHA=0.1
# SM_HP_MODEL=resnet50
# SM_HP_MODEL_DIR=s3://jbsnyder-sagemaker-us-east/sagemaker-output/17-06-2022/jbsnyder-tf-resnet-debugger-17-06-2022-23-24-32/training-model
# SM_HP_MOMENTUM=0.9
# SM_HP_NUM_EPOCHS=5
# SM_HP_TF32=false
# SM_HP_TRAIN_DATA_DIR=s3://jbsnyder-sagemaker-us-east/data/imagenet/tfrecord/train
# SM_HP_VALIDATION_DATA_DIR=s3://jbsnyder-sagemaker-us-east/data/imagenet/tfrecord/validation
# SM_HP_XLA=false
# PYTHONPATH=/opt/ml/code:/usr/local/bin:/usr/local/lib/python38.zip:/usr/local/lib/python3.8:/usr/local/lib/python3.8/lib-dynload:/usr/local/lib/python3.8/site-packages:/usr/local/lib/python3.8/site-packages/smdebug-1.0.12b20220601-py3.8.egg:/usr/local/lib/python3.8/site-packages/pyinstrument-3.4.2-py3.8.egg:/usr/local/lib/python3.8/site-packages/pyinstrument_cext-0.2.4-py3.8-linux-x86_64.egg
# Invoking script with the following command:
# mpirun --host algo-1:8 -np 8 --allow-run-as-root --display-map --tag-output -mca btl_tcp_if_include eth0 -mca oob_tcp_if_include eth0 -mca plm_rsh_no_tree_spawn 1 -bind-to none -map-by slot -mca pml ob1 -mca btl ^openib -mca orte_abort_on_non_zero_status 1 -mca btl_vader_single_copy_mechanism none -x NCCL_MIN_NRINGS=4 -x NCCL_SOCKET_IFNAME=eth0 -x NCCL_DEBUG=INFO -x LD_LIBRARY_PATH -x PATH -x LD_PRELOAD=/usr/local/lib/python3.8/site-packages/gethostname.cpython-38-x86_64-linux-gnu.so -x SM_HOSTS -x SM_NETWORK_INTERFACE_NAME -x SM_HPS -x SM_USER_ENTRY_POINT -x SM_FRAMEWORK_PARAMS -x SM_RESOURCE_CONFIG -x SM_INPUT_DATA_CONFIG -x SM_OUTPUT_DATA_DIR -x SM_CHANNELS -x SM_CURRENT_HOST -x SM_MODULE_NAME -x SM_LOG_LEVEL -x SM_FRAMEWORK_MODULE -x SM_INPUT_DIR -x SM_INPUT_CONFIG_DIR -x SM_OUTPUT_DIR -x SM_NUM_CPUS -x SM_NUM_GPUS -x SM_MODEL_DIR -x SM_MODULE_DIR -x SM_TRAINING_ENV -x SM_USER_ARGS -x SM_OUTPUT_INTERMEDIATE_DIR -x SM_HP_BATCH_SIZE -x SM_HP_FP16 -x SM_HP_L2_WEIGHT_DECAY -x SM_HP_LABEL_SMOOTHING -x SM_HP_LEARNING_RATE -x SM_HP_MIXUP_ALPHA -x SM_HP_MODEL -x SM_HP_MODEL_DIR -x SM_HP_MOMENTUM -x SM_HP_NUM_EPOCHS -x SM_HP_TF32 -x SM_HP_TRAIN_DATA_DIR -x SM_HP_VALIDATION_DATA_DIR -x SM_HP_XLA -x PYTHONPATH /usr/local/bin/python3.8 -m mpi4py train.py --batch_size 512 --fp16 True --l2_weight_decay 0.0001 --label_smoothing 0.1 --learning_rate 0.08 --mixup_alpha 0.1 --model resnet50 --model_dir s3://jbsnyder-sagemaker-us-east/sagemaker-output/17-06-2022/jbsnyder-tf-resnet-debugger-17-06-2022-23-24-32/training-model --momentum 0.9 --num_epochs 5 --tf32 False --train_data_dir s3://jbsnyder-sagemaker-us-east/data/imagenet/tfrecord/train --validation_data_dir s3://jbsnyder-sagemaker-us-east/data/imagenet/tfrecord/validation --xla False
# Data for JOB [13916,1] offset 0 Total slots allocated 8
#  ========================   JOB MAP   ========================
#  Data for node: ip-10-0-245-191#011Num slots: 8#011Max slots: 0#011Num procs: 8
#  #011Process OMPI jobid: [13916,1] App: 0 Process rank: 0 Bound: N/A
#  #011Process OMPI jobid: [13916,1] App: 0 Process rank: 1 Bound: N/A
#  #011Process OMPI jobid: [13916,1] App: 0 Process rank: 2 Bound: N/A
#  #011Process OMPI jobid: [13916,1] App: 0 Process rank: 3 Bound: N/A
#  #011Process OMPI jobid: [13916,1] App: 0 Process rank: 4 Bound: N/A
#  #011Process OMPI jobid: [13916,1] App: 0 Process rank: 5 Bound: N/A
#  #011Process OMPI jobid: [13916,1] App: 0 Process rank: 6 Bound: N/A
#  #011Process OMPI jobid: [13916,1] App: 0 Process rank: 7 Bound: N/A
#  =============================================================
# [1,mpirank:0,algo-1]<stderr>:2022-06-17 23:30:18.301188: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,mpirank:2,algo-1]<stderr>:2022-06-17 23:30:18.301191: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,mpirank:4,algo-1]<stderr>:2022-06-17 23:30:18.301194: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,mpirank:5,algo-1]<stderr>:2022-06-17 23:30:18.301189: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,mpirank:6,algo-1]<stderr>:2022-06-17 23:30:18.301196: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,mpirank:0,algo-1]<stderr>:2022-06-17 23:30:18.301412: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,mpirank:2,algo-1]<stderr>:2022-06-17 23:30:18.301412: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,mpirank:4,algo-1]<stderr>:2022-06-17 23:30:18.301414: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,mpirank:5,algo-1]<stderr>:2022-06-17 23:30:18.301412: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,mpirank:6,algo-1]<stderr>:2022-06-17 23:30:18.301415: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,mpirank:7,algo-1]<stderr>:2022-06-17 23:30:18.306281: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,mpirank:1,algo-1]<stderr>:2022-06-17 23:30:18.306281: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,mpirank:3,algo-1]<stderr>:2022-06-17 23:30:18.306434: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,mpirank:7,algo-1]<stderr>:2022-06-17 23:30:18.306522: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,mpirank:1,algo-1]<stderr>:2022-06-17 23:30:18.306522: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,mpirank:3,algo-1]<stderr>:2022-06-17 23:30:18.306638: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:105] SageMaker Profiler is not enabled. The timeline writer thread will not be started, future recorded events will be dropped.
# [1,mpirank:6,algo-1]<stderr>:2022-06-17 23:30:18.349182: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,mpirank:5,algo-1]<stderr>:2022-06-17 23:30:18.349182: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,mpirank:2,algo-1]<stderr>:2022-06-17 23:30:18.349182: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,mpirank:4,algo-1]<stderr>:2022-06-17 23:30:18.349180: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,mpirank:0,algo-1]<stderr>:2022-06-17 23:30:18.349327: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,mpirank:3,algo-1]<stderr>:2022-06-17 23:30:18.354560: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,mpirank:1,algo-1]<stderr>:2022-06-17 23:30:18.354578: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,mpirank:7,algo-1]<stderr>:2022-06-17 23:30:18.357990: W tensorflow/core/profiler/internal/smprofiler_timeline.cc:460] Initializing the SageMaker Profiler.
# [1,mpirank:1,algo-1]<stdout>:Extension horovod.torch has not been built: /usr/local/lib/python3.8/site-packages/horovod/torch/mpi_lib/_mpi_lib.cpython-38-x86_64-linux-gnu.so not found
# [1,mpirank:1,algo-1]<stdout>:If this is not expected, reinstall Horovod with HOROVOD_WITH_PYTORCH=1 to debug the build error.
# [1,mpirank:1,algo-1]<stdout>:Warning! MPI libs are missing, but python applications are still avaiable.
# [1,mpirank:2,algo-1]<stdout>:Extension horovod.torch has not been built: /usr/local/lib/python3.8/site-packages/horovod/torch/mpi_lib/_mpi_lib.cpython-38-x86_64-linux-gnu.so not found
# [1,mpirank:2,algo-1]<stdout>:If this is not expected, reinstall Horovod with HOROVOD_WITH_PYTORCH=1 to debug the build error.
# [1,mpirank:2,algo-1]<stdout>:Warning! MPI libs are missing, but python applications are still avaiable.
# [1,mpirank:3,algo-1]<stdout>:Extension horovod.torch has not been built: /usr/local/lib/python3.8/site-packages/horovod/torch/mpi_lib/_mpi_lib.cpython-38-x86_64-linux-gnu.so not found
# [1,mpirank:3,algo-1]<stdout>:If this is not expected, reinstall Horovod with HOROVOD_WITH_PYTORCH=1 to debug the build error.
# [1,mpirank:3,algo-1]<stdout>:Warning! MPI libs are missing, but python applications are still avaiable.
# [1,mpirank:4,algo-1]<stdout>:Extension horovod.torch has not been built: /usr/local/lib/python3.8/site-packages/horovod/torch/mpi_lib/_mpi_lib.cpython-38-x86_64-linux-gnu.so not found
# [1,mpirank:4,algo-1]<stdout>:If this is not expected, reinstall Horovod with HOROVOD_WITH_PYTORCH=1 to debug the build error.
# [1,mpirank:4,algo-1]<stdout>:Warning! MPI libs are missing, but python applications are still avaiable.
# [1,mpirank:7,algo-1]<stdout>:Extension horovod.torch has not been built: /usr/local/lib/python3.8/site-packages/horovod/torch/mpi_lib/_mpi_lib.cpython-38-x86_64-linux-gnu.so not found
# [1,mpirank:7,algo-1]<stdout>:If this is not expected, reinstall Horovod with HOROVOD_WITH_PYTORCH=1 to debug the build error.
# [1,mpirank:7,algo-1]<stdout>:Warning! MPI libs are missing, but python applications are still avaiable.
# [1,mpirank:5,algo-1]<stdout>:Extension horovod.torch has not been built: /usr/local/lib/python3.8/site-packages/horovod/torch/mpi_lib/_mpi_lib.cpython-38-x86_64-linux-gnu.so not found
# [1,mpirank:5,algo-1]<stdout>:If this is not expected, reinstall Horovod with HOROVOD_WITH_PYTORCH=1 to debug the build error.
# [1,mpirank:5,algo-1]<stdout>:Warning! MPI libs are missing, but python applications are still avaiable.
# [1,mpirank:0,algo-1]<stdout>:Extension horovod.torch has not been built: /usr/local/lib/python3.8/site-packages/horovod/torch/mpi_lib/_mpi_lib.cpython-38-x86_64-linux-gnu.so not found
# [1,mpirank:0,algo-1]<stdout>:If this is not expected, reinstall Horovod with HOROVOD_WITH_PYTORCH=1 to debug the build error.
# [1,mpirank:0,algo-1]<stdout>:Warning! MPI libs are missing, but python applications are still avaiable.
# [1,mpirank:6,algo-1]<stdout>:Extension horovod.torch has not been built: /usr/local/lib/python3.8/site-packages/horovod/torch/mpi_lib/_mpi_lib.cpython-38-x86_64-linux-gnu.so not found
# [1,mpirank:6,algo-1]<stdout>:If this is not expected, reinstall Horovod with HOROVOD_WITH_PYTORCH=1 to debug the build error.
# [1,mpirank:6,algo-1]<stdout>:Warning! MPI libs are missing, but python applications are still avaiable.
# [1,mpirank:5,algo-1]<stdout>:[2022-06-17 23:30:21.275 algo-1:161 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,mpirank:7,algo-1]<stdout>:[2022-06-17 23:30:21.275 algo-1:163 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,mpirank:4,algo-1]<stdout>:[2022-06-17 23:30:21.275 algo-1:160 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,mpirank:3,algo-1]<stdout>:[2022-06-17 23:30:21.275 algo-1:159 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,mpirank:6,algo-1]<stdout>:[2022-06-17 23:30:21.275 algo-1:162 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,mpirank:0,algo-1]<stdout>:[2022-06-17 23:30:21.275 algo-1:156 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,mpirank:2,algo-1]<stdout>:[2022-06-17 23:30:21.275 algo-1:158 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,mpirank:1,algo-1]<stdout>:[2022-06-17 23:30:21.282 algo-1:157 INFO utils.py:27] RULE_JOB_STOP_SIGNAL_FILENAME: None
# [1,mpirank:7,algo-1]<stderr>:/usr/local/lib/python3.8/site-packages/smdebug-1.0.12b20220601-py3.8.egg/smdebug/profiler/system_metrics_reader.py:63: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# [1,mpirank:6,algo-1]<stderr>:/usr/local/lib/python3.8/site-packages/smdebug-1.0.12b20220601-py3.8.egg/smdebug/profiler/system_metrics_reader.py:63: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# [1,mpirank:2,algo-1]<stderr>:/usr/local/lib/python3.8/site-packages/smdebug-1.0.12b20220601-py3.8.egg/smdebug/profiler/system_metrics_reader.py:63: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# [1,mpirank:4,algo-1]<stderr>:/usr/local/lib/python3.8/site-packages/smdebug-1.0.12b20220601-py3.8.egg/smdebug/profiler/system_metrics_reader.py:63: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# [1,mpirank:0,algo-1]<stderr>:/usr/local/lib/python3.8/site-packages/smdebug-1.0.12b20220601-py3.8.egg/smdebug/profiler/system_metrics_reader.py:63: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# [1,mpirank:5,algo-1]<stderr>:/usr/local/lib/python3.8/site-packages/smdebug-1.0.12b20220601-py3.8.egg/smdebug/profiler/system_metrics_reader.py:63: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# [1,mpirank:7,algo-1]<stderr>:/usr/local/lib/python3.8/site-packages/smdebug-1.0.12b20220601-py3.8.egg/smdebug/profiler/system_metrics_reader.py:63: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# [1,mpirank:6,algo-1]<stderr>:/usr/local/lib/python3.8/site-packages/smdebug-1.0.12b20220601-py3.8.egg/smdebug/profiler/system_metrics_reader.py:63: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# [1,mpirank:3,algo-1]<stderr>:/usr/local/lib/python3.8/site-packages/smdebug-1.0.12b20220601-py3.8.egg/smdebug/profiler/system_metrics_reader.py:63: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# [1,mpirank:2,algo-1]<stderr>:/usr/local/lib/python3.8/site-packages/smdebug-1.0.12b20220601-py3.8.egg/smdebug/profiler/system_metrics_reader.py:63: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# [1,mpirank:4,algo-1]<stderr>:/usr/local/lib/python3.8/site-packages/smdebug-1.0.12b20220601-py3.8.egg/smdebug/profiler/system_metrics_reader.py:63: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# [1,mpirank:0,algo-1]<stderr>:/usr/local/lib/python3.8/site-packages/smdebug-1.0.12b20220601-py3.8.egg/smdebug/profiler/system_metrics_reader.py:63: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# [1,mpirank:5,algo-1]<stderr>:/usr/local/lib/python3.8/site-packages/smdebug-1.0.12b20220601-py3.8.egg/smdebug/profiler/system_metrics_reader.py:63: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# [1,mpirank:3,algo-1]<stderr>:/usr/local/lib/python3.8/site-packages/smdebug-1.0.12b20220601-py3.8.egg/smdebug/profiler/system_metrics_reader.py:63: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# [1,mpirank:1,algo-1]<stderr>:/usr/local/lib/python3.8/site-packages/smdebug-1.0.12b20220601-py3.8.egg/smdebug/profiler/system_metrics_reader.py:63: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# [1,mpirank:1,algo-1]<stderr>:/usr/local/lib/python3.8/site-packages/smdebug-1.0.12b20220601-py3.8.egg/smdebug/profiler/system_metrics_reader.py:63: SyntaxWarning: "is not" with a literal. Did you mean "!="?
# [1,mpirank:3,algo-1]<stdout>:[2022-06-17 23:30:21.542 algo-1:159 INFO profiler_config_parser.py:111] User has disabled profiler.
# [1,mpirank:2,algo-1]<stdout>:[2022-06-17 23:30:21.542 algo-1:158 INFO profiler_config_parser.py:111] User has disabled profiler.
# [1,mpirank:0,algo-1]<stdout>:[2022-06-17 23:30:21.542 algo-1:156 INFO profiler_config_parser.py:111] User has disabled profiler.
# [1,mpirank:4,algo-1]<stdout>:[2022-06-17 23:30:21.542 algo-1:160 INFO profiler_config_parser.py:111] User has disabled profiler.
# [1,mpirank:5,algo-1]<stdout>:[2022-06-17 23:30:21.542 algo-1:161 INFO profiler_config_parser.py:111] User has disabled profiler.
# [1,mpirank:6,algo-1]<stdout>:[2022-06-17 23:30:21.542 algo-1:162 INFO profiler_config_parser.py:111] User has disabled profiler.
# [1,mpirank:7,algo-1]<stdout>:[2022-06-17 23:30:21.542 algo-1:163 INFO profiler_config_parser.py:111] User has disabled profiler.
# [1,mpirank:1,algo-1]<stdout>:[2022-06-17 23:30:21.542 algo-1:157 INFO profiler_config_parser.py:111] User has disabled profiler.
# [1,mpirank:1,algo-1]<stderr>:WARNING:absl:options.experimental_threading is deprecated. Use options.threading instead.
# [1,mpirank:2,algo-1]<stderr>:WARNING:absl:options.experimental_threading is deprecated. Use options.threading instead.
# [1,mpirank:6,algo-1]<stderr>:WARNING:absl:options.experimental_threading is deprecated. Use options.threading instead.
# [1,mpirank:0,algo-1]<stderr>:WARNING:absl:options.experimental_threading is deprecated. Use options.threading instead.
# [1,mpirank:3,algo-1]<stderr>:WARNING:absl:options.experimental_threading is deprecated. Use options.threading instead.
# [1,mpirank:5,algo-1]<stderr>:WARNING:absl:options.experimental_threading is deprecated. Use options.threading instead.
# [1,mpirank:7,algo-1]<stderr>:WARNING:absl:options.experimental_threading is deprecated. Use options.threading instead.
# [1,mpirank:4,algo-1]<stderr>:WARNING:absl:options.experimental_threading is deprecated. Use options.threading instead.
# [1,mpirank:0,algo-1]<stdout>:[2022-06-17 23:30:27.581 algo-1:156 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [1,mpirank:0,algo-1]<stdout>:[2022-06-17 23:30:27.583 algo-1:156 INFO hook.py:254] Saving to /opt/ml/output/tensors
# [1,mpirank:2,algo-1]<stdout>:[2022-06-17 23:30:27.591 algo-1:158 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [1,mpirank:2,algo-1]<stdout>:[2022-06-17 23:30:27.592 algo-1:158 INFO hook.py:254] Saving to /opt/ml/output/tensors
# [1,mpirank:6,algo-1]<stdout>:[2022-06-17 23:30:27.592 algo-1:162 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [1,mpirank:6,algo-1]<stdout>:[2022-06-17 23:30:27.593 algo-1:162 INFO hook.py:254] Saving to /opt/ml/output/tensors
# [1,mpirank:5,algo-1]<stdout>:[2022-06-17 23:30:27.608 algo-1:161 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [1,mpirank:1,algo-1]<stdout>:[2022-06-17 23:30:27.609 algo-1:157 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [1,mpirank:5,algo-1]<stdout>:[2022-06-17 23:30:27.609 algo-1:161 INFO hook.py:254] Saving to /opt/ml/output/tensors
# [1,mpirank:1,algo-1]<stdout>:[2022-06-17 23:30:27.610 algo-1:157 INFO hook.py:254] Saving to /opt/ml/output/tensors
# [1,mpirank:7,algo-1]<stdout>:[2022-06-17 23:30:27.619 algo-1:163 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [1,mpirank:7,algo-1]<stdout>:[2022-06-17 23:30:27.620 algo-1:163 INFO hook.py:254] Saving to /opt/ml/output/tensors
# [1,mpirank:4,algo-1]<stdout>:[2022-06-17 23:30:27.655 algo-1:160 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [1,mpirank:4,algo-1]<stdout>:[2022-06-17 23:30:27.657 algo-1:160 INFO hook.py:254] Saving to /opt/ml/output/tensors
# [1,mpirank:3,algo-1]<stdout>:[2022-06-17 23:30:27.666 algo-1:159 INFO json_config.py:91] Creating hook from json_config at /opt/ml/input/config/debughookconfig.json.
# [1,mpirank:3,algo-1]<stdout>:[2022-06-17 23:30:27.668 algo-1:159 INFO hook.py:254] Saving to /opt/ml/output/tensors
# [1,mpirank:6,algo-1]<stderr>:2022-06-17 23:30:29.169420: W tensorflow/core/grappler/optimizers/data/slack.cc:103] Could not find a final `prefetch` in the input pipeline to which to introduce slack.
# [1,mpirank:7,algo-1]<stderr>:2022-06-17 23:30:29.169460: W tensorflow/core/grappler/optimizers/data/slack.cc:103] Could not find a final `prefetch` in the input pipeline to which to introduce slack.
# [1,mpirank:2,algo-1]<stderr>:2022-06-17 23:30:29.172276: W tensorflow/core/grappler/optimizers/data/slack.cc:103] Could not find a final `prefetch` in the input pipeline to which to introduce slack.
# [1,mpirank:3,algo-1]<stderr>:2022-06-17 23:30:29.198464: W tensorflow/core/grappler/optimizers/data/slack.cc:103] Could not find a final `prefetch` in the input pipeline to which to introduce slack.
# [1,mpirank:4,algo-1]<stderr>:2022-06-17 23:30:29.198567: W tensorflow/core/grappler/optimizers/data/slack.cc:103] Could not find a final `prefetch` in the input pipeline to which to introduce slack.
# [1,mpirank:0,algo-1]<stderr>:2022-06-17 23:30:29.207144: W tensorflow/core/grappler/optimizers/data/slack.cc:103] Could not find a final `prefetch` in the input pipeline to which to introduce slack.
# [1,mpirank:5,algo-1]<stderr>:2022-06-17 23:30:29.236493: W tensorflow/core/grappler/optimizers/data/slack.cc:103] Could not find a final `prefetch` in the input pipeline to which to introduce slack.
# [1,mpirank:1,algo-1]<stderr>:2022-06-17 23:30:29.281789: W tensorflow/core/grappler/optimizers/data/slack.cc:103] Could not find a final `prefetch` in the input pipeline to which to introduce slack.
# [1,mpirank:2,algo-1]<stderr>:2022-06-17 23:30:29.321126: W tensorflow/core/grappler/optimizers/data/slack.cc:103] Could not find a final `prefetch` in the input pipeline to which to introduce slack.
# [1,mpirank:6,algo-1]<stderr>:2022-06-17 23:30:29.321093: W tensorflow/core/grappler/optimizers/data/slack.cc:103] Could not find a final `prefetch` in the input pipeline to which to introduce slack.
# [1,mpirank:0,algo-1]<stderr>:2022-06-17 23:30:29.321092: W tensorflow/core/grappler/optimizers/data/slack.cc:103] Could not find a final `prefetch` in the input pipeline to which to introduce slack.
# [1,mpirank:4,algo-1]<stderr>:2022-06-17 23:30:29.321247: W tensorflow/core/grappler/optimizers/data/slack.cc:103] Could not find a final `prefetch` in the input pipeline to which to introduce slack.
# [1,mpirank:7,algo-1]<stderr>:2022-06-17 23:30:29.321376: W tensorflow/core/grappler/optimizers/data/slack.cc:103] Could not find a final `prefetch` in the input pipeline to which to introduce slack.
# [1,mpirank:3,algo-1]<stderr>:2022-06-17 23:30:29.321583: W tensorflow/core/grappler/optimizers/data/slack.cc:103] Could not find a final `prefetch` in the input pipeline to which to introduce slack.
# [1,mpirank:5,algo-1]<stderr>:2022-06-17 23:30:29.325332: W tensorflow/core/grappler/optimizers/data/slack.cc:103] Could not find a final `prefetch` in the input pipeline to which to introduce slack.
# [1,mpirank:1,algo-1]<stderr>:2022-06-17 23:30:29.356817: W tensorflow/core/grappler/optimizers/data/slack.cc:103] Could not find a final `prefetch` in the input pipeline to which to introduce slack.
# [1,mpirank:4,algo-1]<stdout>:[2022-06-17 23:30:29.392 algo-1:160 INFO hook.py:421] Monitoring the collections: gradients, sm_metrics, losses, metrics
# [1,mpirank:2,algo-1]<stdout>:[2022-06-17 23:30:29.392 algo-1:158 INFO hook.py:421] Monitoring the collections: metrics, losses, gradients, sm_metrics
# [1,mpirank:7,algo-1]<stdout>:[2022-06-17 23:30:29.393 algo-1:163 INFO hook.py:421] Monitoring the collections: metrics, gradients, losses, sm_metrics
# [1,mpirank:3,algo-1]<stdout>:[2022-06-17 23:30:29.394 algo-1:159 INFO hook.py:421] Monitoring the collections: sm_metrics, losses, metrics, gradients
# [1,mpirank:0,algo-1]<stdout>:Epoch 1/5
# [1,mpirank:5,algo-1]<stdout>:[2022-06-17 23:30:29.395 algo-1:161 INFO hook.py:421] Monitoring the collections: losses, metrics, sm_metrics, gradients
# [1,mpirank:0,algo-1]<stdout>:[2022-06-17 23:30:29.396 algo-1:156 INFO hook.py:421] Monitoring the collections: metrics, losses, gradients, sm_metrics
# [1,mpirank:6,algo-1]<stdout>:[2022-06-17 23:30:29.417 algo-1:162 INFO hook.py:421] Monitoring the collections: gradients, metrics, losses, sm_metrics
# [1,mpirank:1,algo-1]<stdout>:[2022-06-17 23:30:29.424 algo-1:157 INFO hook.py:421] Monitoring the collections: sm_metrics, metrics, gradients, losses
# [1,mpirank:2,algo-1]<stderr>:/usr/local/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1096: UserWarning: "`categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
# [1,mpirank:2,algo-1]<stderr>:  return dispatch_target(*args, **kwargs)
# [1,mpirank:4,algo-1]<stderr>:/usr/local/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1096: UserWarning: "`categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
# [1,mpirank:4,algo-1]<stderr>:  return dispatch_target(*args, **kwargs)
# [1,mpirank:0,algo-1]<stderr>:/usr/local/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1096: UserWarning: "`categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
# [1,mpirank:0,algo-1]<stderr>:  return dispatch_target(*args, **kwargs)
# [1,mpirank:7,algo-1]<stderr>:/usr/local/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1096: UserWarning: "`categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
# [1,mpirank:7,algo-1]<stderr>:  return dispatch_target(*args, **kwargs)
# [1,mpirank:1,algo-1]<stderr>:/usr/local/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1096: UserWarning: "`categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
# [1,mpirank:1,algo-1]<stderr>:  return dispatch_target(*args, **kwargs)
# [1,mpirank:3,algo-1]<stderr>:/usr/local/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1096: UserWarning: "`categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
# [1,mpirank:3,algo-1]<stderr>:  return dispatch_target(*args, **kwargs)
# [1,mpirank:5,algo-1]<stderr>:/usr/local/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1096: UserWarning: "`categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
# [1,mpirank:5,algo-1]<stderr>:  return dispatch_target(*args, **kwargs)
# [1,mpirank:6,algo-1]<stderr>:/usr/local/lib/python3.8/site-packages/tensorflow/python/util/dispatch.py:1096: UserWarning: "`categorical_crossentropy` received `from_logits=True`, but the `output` argument was produced by a sigmoid or softmax activation and thus does not represent logits. Was this intended?"
# [1,mpirank:6,algo-1]<stderr>:  return dispatch_target(*args, **kwargs)
# [1,mpirank:0,algo-1]<stdout>:algo-1:156:1239 [0] NCCL INFO Bootstrap : Using eth0:10.0.245.191<0>
# [1,mpirank:0,algo-1]<stdout>:
# [1,mpirank:0,algo-1]<stdout>:algo-1:156:1239 [0] ofi_init:1134 NCCL WARN NET/OFI Only EFA provider is supported
# [1,mpirank:0,algo-1]<stdout>:algo-1:156:1239 [0] NCCL INFO NET/IB : No device found.
# [1,mpirank:0,algo-1]<stdout>:algo-1:156:1239 [0] NCCL INFO NET/Socket : Using [0]eth0:10.0.245.191<0>
# [1,mpirank:0,algo-1]<stdout>:algo-1:156:1239 [0] NCCL INFO Using network Socket
# [1,mpirank:0,algo-1]<stdout>:NCCL version 2.8.4+cuda11.2
# [1,mpirank:5,algo-1]<stdout>:algo-1:161:1236 [5] NCCL INFO Bootstrap : Using eth0:10.0.245.191<0>
# [1,mpirank:6,algo-1]<stdout>:algo-1:162:1243 [6] NCCL INFO Bootstrap : Using eth0:10.0.245.191<0>
# [1,mpirank:7,algo-1]<stdout>:algo-1:163:1242 [7] NCCL INFO Bootstrap : Using eth0:10.0.245.191<0>
# [1,mpirank:3,algo-1]<stdout>:algo-1:159:1241 [3] NCCL INFO Bootstrap : Using eth0:10.0.245.191<0>
# [1,mpirank:2,algo-1]<stdout>:algo-1:158:1237 [2] NCCL INFO Bootstrap : Using eth0:10.0.245.191<0>
# [1,mpirank:1,algo-1]<stdout>:algo-1:157:1238 [1] NCCL INFO Bootstrap : Using eth0:10.0.245.191<0>
# [1,mpirank:4,algo-1]<stdout>:algo-1:160:1240 [4] NCCL INFO Bootstrap : Using eth0:10.0.245.191<0>
# [1,mpirank:6,algo-1]<stdout>:
# [1,mpirank:6,algo-1]<stdout>:algo-1:162:1243 [6] ofi_init:1134 NCCL WARN NET/OFI Only EFA provider is supported
# [1,mpirank:5,algo-1]<stdout>:
# [1,mpirank:5,algo-1]<stdout>:algo-1:161:1236 [5] ofi_init:1134 NCCL WARN NET/OFI Only EFA provider is supported
# [1,mpirank:4,algo-1]<stdout>:
# [1,mpirank:4,algo-1]<stdout>:algo-1:160:1240 [4] ofi_init:1134 NCCL WARN NET/OFI Only EFA provider is supported
# [1,mpirank:7,algo-1]<stdout>:
# [1,mpirank:7,algo-1]<stdout>:algo-1:163:1242 [7] ofi_init:1134 NCCL WARN NET/OFI Only EFA provider is supported
# [1,mpirank:3,algo-1]<stdout>:
# [1,mpirank:3,algo-1]<stdout>:algo-1:159:1241 [3] ofi_init:1134 NCCL WARN NET/OFI Only EFA provider is supported
# [1,mpirank:2,algo-1]<stdout>:
# [1,mpirank:2,algo-1]<stdout>:algo-1:158:1237 [2] ofi_init:1134 NCCL WARN NET/OFI Only EFA provider is supported
# [1,mpirank:1,algo-1]<stdout>:
# [1,mpirank:1,algo-1]<stdout>:algo-1:157:1238 [1] ofi_init:1134 NCCL WARN NET/OFI Only EFA provider is supported
# [1,mpirank:6,algo-1]<stdout>:algo-1:162:1243 [6] NCCL INFO NET/IB : No device found.
# [1,mpirank:6,algo-1]<stdout>:algo-1:162:1243 [6] NCCL INFO NET/Socket : Using [0]eth0:10.0.245.191<0>
# [1,mpirank:6,algo-1]<stdout>:algo-1:162:1243 [6] NCCL INFO Using network Socket
# [1,mpirank:1,algo-1]<stdout>:algo-1:157:1238 [1] NCCL INFO NET/IB : No device found.
# [1,mpirank:4,algo-1]<stdout>:algo-1:160:1240 [4] NCCL INFO NET/IB : No device found.
# [1,mpirank:7,algo-1]<stdout>:algo-1:163:1242 [7] NCCL INFO NET/IB : No device found.
# [1,mpirank:3,algo-1]<stdout>:algo-1:159:1241 [3] NCCL INFO NET/IB : No device found.
# [1,mpirank:2,algo-1]<stdout>:algo-1:158:1237 [2] NCCL INFO NET/IB : No device found.
# [1,mpirank:5,algo-1]<stdout>:algo-1:161:1236 [5] NCCL INFO NET/IB : No device found.
# [1,mpirank:2,algo-1]<stdout>:algo-1:158:1237 [2] NCCL INFO NET/Socket : Using [0]eth0:10.0.245.191<0>
# [1,mpirank:1,algo-1]<stdout>:algo-1:157:1238 [1] NCCL INFO NET/Socket : Using [0]eth0:10.0.245.191<0>
# [1,mpirank:1,algo-1]<stdout>:algo-1:157:1238 [1] NCCL INFO Using network Socket
# [1,mpirank:4,algo-1]<stdout>:algo-1:160:1240 [4] NCCL INFO NET/Socket : Using [0]eth0:10.0.245.191<0>
# [1,mpirank:4,algo-1]<stdout>:algo-1:160:1240 [4] NCCL INFO Using network Socket
# [1,mpirank:7,algo-1]<stdout>:algo-1:163:1242 [7] NCCL INFO NET/Socket : Using [0]eth0:10.0.245.191<0>
# [1,mpirank:7,algo-1]<stdout>:algo-1:163:1242 [7] NCCL INFO Using network Socket
# [1,mpirank:3,algo-1]<stdout>:algo-1:159:1241 [3] NCCL INFO NET/Socket : Using [0]eth0:10.0.245.191<0>
# [1,mpirank:3,algo-1]<stdout>:algo-1:159:1241 [3] NCCL INFO Using network Socket
# [1,mpirank:2,algo-1]<stdout>:algo-1:158:1237 [2] NCCL INFO Using network Socket
# [1,mpirank:5,algo-1]<stdout>:algo-1:161:1236 [5] NCCL INFO NET/Socket : Using [0]eth0:10.0.245.191<0>
# [1,mpirank:5,algo-1]<stdout>:algo-1:161:1236 [5] NCCL INFO Using network Socket
# [1,mpirank:2,algo-1]<stdout>:algo-1:158:1237 [2] NCCL INFO NCCL_MIN_NRINGS set by environment to 4.
# [1,mpirank:2,algo-1]<stdout>:algo-1:158:1237 [2] NCCL INFO Trees [0] 1/-1/-1->2->3 [1] 1/-1/-1->2->3 [2] 3/-1/-1->2->1 [3] 3/-1/-1->2->1 [4] -1/-1/-1->2->6 [5] 6/-1/-1->2->0 [6] 1/-1/-1->2->3 [7] 1/-1/-1->2->3 [8] 3/-1/-1->2->1 [9] 3/-1/-1->2->1 [10] -1/-1/-1->2->6 [11] 6/-1/-1->2->0
# [1,mpirank:1,algo-1]<stdout>:algo-1:157:1238 [1] NCCL INFO NCCL_MIN_NRINGS set by environment to 4.
# [1,mpirank:1,algo-1]<stdout>:algo-1:157:1238 [1] NCCL INFO Trees [0] 5/-1/-1->1->2 [1] 5/-1/-1->1->2 [2] 2/-1/-1->1->5 [3] 2/-1/-1->1->5 [4] 3/-1/-1->1->0 [5] -1/-1/-1->1->3 [6] 5/-1/-1->1->2 [7] 5/-1/-1->1->2 [8] 2/-1/-1->1->5 [9] 2/-1/-1->1->5 [10] 3/-1/-1->1->0 [11] -1/-1/-1->1->3
# [1,mpirank:3,algo-1]<stdout>:algo-1:159:1241 [3] NCCL INFO NCCL_MIN_NRINGS set by environment to 4.
# [1,mpirank:4,algo-1]<stdout>:algo-1:160:1240 [4] NCCL INFO NCCL_MIN_NRINGS set by environment to 4.
# [1,mpirank:3,algo-1]<stdout>:algo-1:159:1241 [3] NCCL INFO Trees [0] 2/-1/-1->3->0 [1] 2/-1/-1->3->0 [2] -1/-1/-1->3->2 [3] -1/-1/-1->3->2 [4] 7/-1/-1->3->1 [5] 1/-1/-1->3->7 [6] 2/-1/-1->3->0 [7] 2/-1/-1->3->0 [8] -1/-1/-1->3->2 [9] -1/-1/-1->3->2 [10] 7/-1/-1->3->1 [11] 1/-1/-1->3->7
# [1,mpirank:4,algo-1]<stdout>:algo-1:160:1240 [4] NCCL INFO Trees [0] -1/-1/-1->4->7 [1] -1/-1/-1->4->7 [2] 7/-1/-1->4->0 [3] 7/-1/-1->4->0 [4] 6/-1/-1->4->5 [5] 5/-1/-1->4->6 [6] -1/-1/-1->4->7 [7] -1/-1/-1->4->7 [8] 7/-1/-1->4->0 [9] 7/-1/-1->4->0 [10] 6/-1/-1->4->5 [11] 5/-1/-1->4->6
# [1,mpirank:5,algo-1]<stdout>:algo-1:161:1236 [5] NCCL INFO NCCL_MIN_NRINGS set by environment to 4.
# [1,mpirank:6,algo-1]<stdout>:algo-1:162:1243 [6] NCCL INFO NCCL_MIN_NRINGS set by environment to 4.
# [1,mpirank:5,algo-1]<stdout>:algo-1:161:1236 [5] NCCL INFO Trees [0] 6/-1/-1->5->1 [1] 6/-1/-1->5->1 [2] 1/-1/-1->5->6 [3] 1/-1/-1->5->6 [4] 4/-1/-1->5->7 [5] 7/-1/-1->5->4 [6] 6/-1/-1->5->1 [7] 6/-1/-1->5->1 [8] 1/-1/-1->5->6 [9] 1/-1/-1->5->6 [10] 4/-1/-1->5->7 [11] 7/-1/-1->5->4
# [1,mpirank:0,algo-1]<stdout>:algo-1:156:1239 [0] NCCL INFO NCCL_MIN_NRINGS set by environment to 4.
# [1,mpirank:7,algo-1]<stdout>:algo-1:163:1242 [7] NCCL INFO NCCL_MIN_NRINGS set by environment to 4.
# [1,mpirank:6,algo-1]<stdout>:algo-1:162:1243 [6] NCCL INFO Trees [0] 7/-1/-1->6->5 [1] 7/-1/-1->6->5 [2] 5/-1/-1->6->7 [3] 5/-1/-1->6->7 [4] 2/-1/-1->6->4 [5] 4/-1/-1->6->2 [6] 7/-1/-1->6->5 [7] 7/-1/-1->6->5 [8] 5/-1/-1->6->7 [9] 5/-1/-1->6->7 [10] 2/-1/-1->6->4 [11] 4/-1/-1->6->2
# [1,mpirank:0,algo-1]<stdout>:algo-1:156:1239 [0] NCCL INFO Channel 00/12 :    0   3   2   1   5   6   7   4
# [1,mpirank:7,algo-1]<stdout>:algo-1:163:1242 [7] NCCL INFO Trees [0] 4/-1/-1->7->6 [1] 4/-1/-1->7->6 [2] 6/-1/-1->7->4 [3] 6/-1/-1->7->4 [4] 5/-1/-1->7->3 [5] 3/-1/-1->7->5 [6] 4/-1/-1->7->6 [7] 4/-1/-1->7->6 [8] 6/-1/-1->7->4 [9] 6/-1/-1->7->4 [10] 5/-1/-1->7->3 [11] 3/-1/-1->7->5
# [1,mpirank:0,algo-1]<stdout>:algo-1:156:1239 [0] NCCL INFO Channel 01/12 :    0   3   2   1   5   6   7   4
# [1,mpirank:0,algo-1]<stdout>:algo-1:156:1239 [0] NCCL INFO Channel 02/12 :    0   4   7   6   5   1   2   3
# [1,mpirank:0,algo-1]<stdout>:algo-1:156:1239 [0] NCCL INFO Channel 03/12 :    0   4   7   6   5   1   2   3
# [1,mpirank:0,algo-1]<stdout>:algo-1:156:1239 [0] NCCL INFO Channel 04/12 :    0   1   3   7   5   4   6   2
# [1,mpirank:0,algo-1]<stdout>:algo-1:156:1239 [0] NCCL INFO Channel 05/12 :    0   2   6   4   5   7   3   1
# [1,mpirank:0,algo-1]<stdout>:algo-1:156:1239 [0] NCCL INFO Channel 06/12 :    0   3   2   1   5   6   7   4
# [1,mpirank:0,algo-1]<stdout>:algo-1:156:1239 [0] NCCL INFO Channel 07/12 :    0   3   2   1   5   6   7   4
# [1,mpirank:0,algo-1]<stdout>:algo-1:156:1239 [0] NCCL INFO Channel 08/12 :    0   4   7   6   5   1   2   3
# [1,mpirank:0,algo-1]<stdout>:algo-1:156:1239 [0] NCCL INFO Channel 09/12 :    0   4   7   6   5   1   2   3
# [1,mpirank:0,algo-1]<stdout>:algo-1:156:1239 [0] NCCL INFO Channel 10/12 :    0   1   3   7   5   4   6   2
# [1,mpirank:0,algo-1]<stdout>:algo-1:156:1239 [0] NCCL INFO Channel 11/12 :    0   2   6   4   5   7   3   1
# [1,mpirank:0,algo-1]<stdout>:algo-1:156:1239 [0] NCCL INFO Trees [0] 3/-1/-1->0->-1 [1] 3/-1/-1->0->-1 [2] 4/-1/-1->0->-1 [3] 4/-1/-1->0->-1 [4] 1/-1/-1->0->-1 [5] 2/-1/-1->0->-1 [6] 3/-1/-1->0->-1 [7] 3/-1/-1->0->-1 [8] 4/-1/-1->0->-1 [9] 4/-1/-1->0->-1 [10] 1/-1/-1->0->-1 [11] 2/-1/-1->0->-1
# [1,mpirank:4,algo-1]<stdout>:algo-1:160:1240 [4] NCCL INFO Channel 05 : 4[1b0] -> 5[1c0] via P2P/IPC
# [1,mpirank:0,algo-1]<stdout>:algo-1:156:1239 [0] NCCL INFO Channel 04 : 0[170] -> 1[180] via P2P/IPC
# [1,mpirank:4,algo-1]<stdout>:algo-1:160:1240 [4] NCCL INFO Channel 11 : 4[1b0] -> 5[1c0] via P2P/IPC
# [1,mpirank:0,algo-1]<stdout>:algo-1:156:1239 [0] NCCL INFO Channel 10 : 0[170] -> 1[180] via P2P/IPC
# [1,mpirank:1,algo-1]<stdout>:algo-1:157:1238 [1] NCCL INFO Channel 02 : 1[180] -> 2[190] via P2P/IPC
# [1,mpirank:5,algo-1]<stdout>:algo-1:161:1236 [5] NCCL INFO Channel 00 : 5[1c0] -> 6[1d0] via P2P/IPC
# [1,mpirank:1,algo-1]<stdout>:algo-1:157:1238 [1] NCCL INFO Channel 03 : 1[180] -> 2[190] via P2P/IPC
# [1,mpirank:5,algo-1]<stdout>:algo-1:161:1236 [5] NCCL INFO Channel 01 : 5[1c0] -> 6[1d0] via P2P/IPC
# [1,mpirank:2,algo-1]<stdout>:algo-1:158:1237 [2] NCCL INFO Channel 02 : 2[190] -> 3[1a0] via P2P/IPC
# [1,mpirank:1,algo-1]<stdout>:algo-1:157:1238 [1] NCCL INFO Channel 08 : 1[180] -> 2[190] via P2P/IPC
# [1,mpirank:6,algo-1]<stdout>:algo-1:162:1243 [6] NCCL INFO Channel 00 : 6[1d0] -> 7[1e0] via P2P/IPC
# [1,mpirank:2,algo-1]<stdout>:algo-1:158:1237 [2] NCCL INFO Channel 03 : 2[190] -> 3[1a0] via P2P/IPC
# [1,mpirank:5,algo-1]<stdout>:algo-1:161:1236 [5] NCCL INFO Channel 06 : 5[1c0] -> 6[1d0] via P2P/IPC
# [1,mpirank:1,algo-1]<stdout>:algo-1:157:1238 [1] NCCL INFO Channel 09 : 1[180] -> 2[190] via P2P/IPC
# [1,mpirank:6,algo-1]<stdout>:algo-1:162:1243 [6] NCCL INFO Channel 01 : 6[1d0] -> 7[1e0] via P2P/IPC
# [1,mpirank:2,algo-1]<stdout>:algo-1:158:1237 [2] NCCL INFO Channel 08 : 2[190] -> 3[1a0] via P2P/IPC
# [1,mpirank:5,algo-1]<stdout>:algo-1:161:1236 [5] NCCL INFO Channel 07 : 5[1c0] -> 6[1d0] via P2P/IPC
# [1,mpirank:6,algo-1]<stdout>:algo-1:162:1243 [6] NCCL INFO Channel 06 : 6[1d0] -> 7[1e0] via P2P/IPC
# [1,mpirank:2,algo-1]<stdout>:algo-1:158:1237 [2] NCCL INFO Channel 09 : 2[190] -> 3[1a0] via P2P/IPC
# [1,mpirank:6,algo-1]<stdout>:algo-1:162:1243 [6] NCCL INFO Channel 07 : 6[1d0] -> 7[1e0] via P2P/IPC
# [1,mpirank:0,algo-1]<stdout>:algo-1:156:1239 [0] NCCL INFO Channel 05 : 0[170] -> 2[190] via P2P/IPC
# [1,mpirank:0,algo-1]<stdout>:algo-1:156:1239 [0] NCCL INFO Channel 11 : 0[170] -> 2[190] via P2P/IPC
# [1,mpirank:4,algo-1]<stdout>:algo-1:160:1240 [4] NCCL INFO Channel 04 : 4[1b0] -> 6[1d0] via P2P/IPC
# [1,mpirank:4,algo-1]<stdout>:algo-1:160:1240 [4] NCCL INFO Channel 10 : 4[1b0] -> 6[1d0] via P2P/IPC
# [1,mpirank:5,algo-1]<stdout>:algo-1:161:1236 [5] NCCL INFO Channel 05 : 5[1c0] -> 7[1e0] via P2P/IPC
# [1,mpirank:1,algo-1]<stdout>:algo-1:157:1238 [1] NCCL INFO Channel 04 : 1[180] -> 3[1a0] via P2P/IPC
# [1,mpirank:5,algo-1]<stdout>:algo-1:161:1236 [5] NCCL INFO Channel 11 : 5[1c0] -> 7[1e0] via P2P/IPC
# [1,mpirank:1,algo-1]<stdout>:algo-1:157:1238 [1] NCCL INFO Channel 10 : 1[180] -> 3[1a0] via P2P/IPC
# [1,mpirank:2,algo-1]<stdout>:algo-1:158:1237 [2] NCCL INFO Channel 05 : 2[190] -> 6[1d0] via P2P/IPC
# [1,mpirank:6,algo-1]<stdout>:algo-1:162:1243 [6] NCCL INFO Channel 04 : 6[1d0] -> 2[190] via P2P/IPC
# [1,mpirank:5,algo-1]<stdout>:algo-1:161:1236 [5] NCCL INFO Channel 02 : 5[1c0] -> 1[180] via P2P/IPC
# [1,mpirank:1,algo-1]<stdout>:algo-1:157:1238 [1] NCCL INFO Channel 00 : 1[180] -> 5[1c0] via P2P/IPC
# [1,mpirank:2,algo-1]<stdout>:algo-1:158:1237 [2] NCCL INFO Channel 11 : 2[190] -> 6[1d0] via P2P/IPC
# [1,mpirank:6,algo-1]<stdout>:algo-1:162:1243 [6] NCCL INFO Channel 10 : 6[1d0] -> 2[190] via P2P/IPC
# [1,mpirank:5,algo-1]<stdout>:algo-1:161:1236 [5] NCCL INFO Channel 03 : 5[1c0] -> 1[180] via P2P/IPC
# [1,mpirank:1,algo-1]<stdout>:algo-1:157:1238 [1] NCCL INFO Channel 01 : 1[180] -> 5[1c0] via P2P/IPC
# [1,mpirank:5,algo-1]<stdout>:algo-1:161:1236 [5] NCCL INFO Channel 08 : 5[1c0] -> 1[180] via P2P/IPC
# [1,mpirank:1,algo-1]<stdout>:algo-1:157:1238 [1] NCCL INFO Channel 06 : 1[180] -> 5[1c0] via P2P/IPC
# [1,mpirank:5,algo-1]<stdout>:algo-1:161:1236 [5] NCCL INFO Channel 09 : 5[1c0] -> 1[180] via P2P/IPC
# [1,mpirank:1,algo-1]<stdout>:algo-1:157:1238 [1] NCCL INFO Channel 07 : 1[180] -> 5[1c0] via P2P/IPC
# [1,mpirank:0,algo-1]<stdout>:algo-1:156:1239 [0] NCCL INFO Channel 00 : 0[170] -> 3[1a0] via P2P/IPC
# [1,mpirank:0,algo-1]<stdout>:algo-1:156:1239 [0] NCCL INFO Channel 01 : 0[170] -> 3[1a0] via P2P/IPC
# [1,mpirank:2,algo-1]<stdout>:algo-1:158:1237 [2] NCCL INFO Channel 04 : 2[190] -> 0[170] via P2P/IPC
# ...
# [1,mpirank:0,algo-1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015     90/Unknown[1,mpirank:0,algo-1]<stdout>: - 74s 460ms/step - loss: 7.4997 - accuracy: 0.0012 - batch: 0.0000e+00
# [1,mpirank:0,algo-1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015     91/Unknown[1,mpirank:0,algo-1]<stdout>: - 74s 463ms/step - loss: 7.4936 - accuracy: 0.0012 - batch: 0.0000e+00
# [1,mpirank:0,algo-1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015     92/Unknown[1,mpirank:0,algo-1]<stdout>: - 75s 459ms/step - loss: 7.4876 - accuracy: 0.0012 - batch: 0.0000e+00
# [1,mpirank:0,algo-1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015     93/Unknown[1,mpirank:0,algo-1]<stdout>: - 75s 462ms/step - loss: 7.4816 - accuracy: 0.0012 - batch: 0.0000e+00
# [1,mpirank:0,algo-1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015     94/Unknown
# [1,mpirank:0,algo-1]<stdout>: - 75s 459ms/step - loss: 7.4756 - accuracy: 0.0012 - batch: 0.0000e+00
# [1,mpirank:0,algo-1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015     95/Unknown[1,mpirank:0,algo-1]<stdout>: - 76s 455ms/step - loss: 7.4716 - accuracy: 0.0012 - batch: 0.0000e+00
# [1,mpirank:0,algo-1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015     96/Unknown
# [1,mpirank:0,algo-1]<stdout>: - 76s 458ms/step - loss: 7.4685 - accuracy: 0.0011 - batch: 0.0000e+00
# [1,mpirank:0,algo-1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015     97/Unknown
# [1,mpirank:0,algo-1]<stdout>: - 76s 455ms/step - loss: 7.4642 - accuracy: 0.0011 - batch: 0.0000e+00
# [1,mpirank:0,algo-1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015     98/Unknown[1,mpirank:0,algo-1]<stdout>: - 77s 460ms/step - loss: 7.4590 - accuracy: 0.0011 - batch: 0.0000e+00
# [1,mpirank:0,algo-1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015     99/Unknown[1,mpirank:0,algo-1]<stdout>: - 78s 457ms/step - loss: 7.4539 - accuracy: 0.0011 - batch: 0.0000e+00
# [1,mpirank:0,algo-1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015    100/Unknown
# [1,mpirank:0,algo-1]<stdout>: - 78s 454ms/step - loss: 7.4489 - accuracy: 0.0011 - batch: 0.0000e+00
# [1,mpirank:0,algo-1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010[1,mpirank:0,algo-1]<stdout>:#015[1,mpirank:0,algo-1]<stdout>:    101/Unknown[1,mpirank:0,algo-1]<stdout>: - 79s 459ms/step - loss: 7.4436 - accuracy: 0.0011 - batch: 0.0000e+00
# [1,mpirank:0,algo-1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015    102/Unknown[1,mpirank:0,algo-1]<stdout>: - 79s 455ms/step - loss: 7.4386 - accuracy: 0.0011 - batch: 0.0000e+00
# [1,mpirank:0,algo-1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015    103/Unknown - 80s 461ms/step - loss: 7.4333 - accuracy: 0.0011 - batch: 0.0000e+00
# [1,mpirank:0,algo-1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015    104/Unknown[1,mpirank:0,algo-1]<stdout>: - 80s 458ms/step - loss: 7.4275 - accuracy: 0.0011 - batch: 0.0000e+00
# [1,mpirank:0,algo-1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015    105/Unknown
# [1,mpirank:0,algo-1]<stdout>: - 81s 462ms/step - loss: 7.4225 - accuracy: 0.0010 - batch: 0.0000e+00
# [1,mpirank:0,algo-1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015    106/Unknown[1,mpirank:0,algo-1]<stdout>: - 81s 459ms/step - loss: 7.4176 - accuracy: 0.0010 - batch: 0.0000e+00
# [1,mpirank:0,algo-1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015    107/Unknown[1,mpirank:0,algo-1]<stdout>: - 81s 455ms/step - loss: 7.4127 - accuracy: 0.0010 - batch: 0.0000e+00
# [1,mpirank:0,algo-1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015    108/Unknown[1,mpirank:0,algo-1]<stdout>: - 82s 458ms/step - loss: 7.4083 - accuracy: 0.0010 - batch: 0.0000e+00
# [1,mpirank:0,algo-1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015    109/Unknown[1,mpirank:0,algo-1]<stdout>: - 82s 455ms/step - loss: 7.4049 - accuracy: 0.0010 - batch: 0.0000e+00
# [1,mpirank:0,algo-1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015    110/Unknown
# [1,mpirank:0,algo-1]<stdout>: - 83s 461ms/step - loss: 7.4002 - accuracy: 9.9432e-04 - batch: 0.0000e+00
# [1,mpirank:0,algo-1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015    111/Unknown[1,mpirank:0,algo-1]<stdout>: - 83s 458ms/step - loss: 7.3957 - accuracy: 9.8536e-04 - batch: 0.0000e+00
# [1,mpirank:0,algo-1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015    112/Unknown[1,mpirank:0,algo-1]<stdout>: - 83s 455ms/step - loss: 7.3913 - accuracy: 9.7656e-04 - batch: 0.0000e+00
# [1,mpirank:0,algo-1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015    113/Unknown[1,mpirank:0,algo-1]<stdout>: - 84s 459ms/step - loss: 7.3876 - accuracy: 9.6792e-04 - batch: 0.0000e+00
# [1,mpirank:0,algo-1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015    114/Unknown[1,mpirank:0,algo-1]<stdout>: - 84s 456ms/step - loss: 7.3851 - accuracy: 0.0011 - batch: 0.0000e+00
# [1,mpirank:0,algo-1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015    115/Unknown
# [1,mpirank:0,algo-1]<stdout>: - 85s 461ms/step - loss: 7.3993 - accuracy: 0.0011 - batch: 0.0000e+00
# [1,mpirank:0,algo-1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015    116/Unknown[1,mpirank:0,algo-1]<stdout>: - 86s 458ms/step - loss: 7.3950 - accuracy: 0.0011 - batch: 0.0000e+00
# [1,mpirank:0,algo-1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015    117/Unknown
# [1,mpirank:0,algo-1]<stdout>: - 86s 455ms/step - loss: 7.3911 - accuracy: 0.0011 - batch: 0.0000e+00
# [1,mpirank:0,algo-1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015    118/Unknown[1,mpirank:0,algo-1]<stdout>: - 87s 459ms/step - loss: 7.3870 - accuracy: 0.0011 - batch: 0.0000e+00
# [1,mpirank:0,algo-1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015    119/Unknown[1,mpirank:0,algo-1]<stdout>: - 87s 456ms/step - loss: 7.3831 - accuracy: 0.0011 - batch: 0.0000e+00
# [1,mpirank:0,algo-1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015    120/Unknown[1,mpirank:0,algo-1]<stdout>: - 87s 458ms/step - loss: 7.3792 - accuracy: 0.0010 - batch: 0.0000e+00
# [1,mpirank:0,algo-1]<stdout>:#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#010#015    121/Unknown[1,mpirank:0,algo-1]<stdout>: - 87s 455ms/step - loss: 7.3776 - accuracy: 0.0010 - batch: 0.0000e+00
